# %% [markdown]
# ___
#
# <a href='https://mainacademy.ua/'> <img src='https://mainacademy.ua/wp-content/uploads/2019/03/logo-main.png' alt = 'Хмм, щось з інтернетом'/></a>
# ___
#
# # Module 2: Basic Python

# %% [markdown]
# ## Lab work 2.2

# %% [markdown]
# #### Мета:
#
# * навчитися працювати із основними інструкціями Python;
# * ознайомитися із базовими алгоритмами;

# %% [markdown]
# ### Завдання 1

# %% [markdown]
# Для трьох введених натуральних чисел (користувач вводить числа через пробіл) знайдіть мінімальне та максимальне

# %%
numbers = input() # Введення чисел

list_of_numbers = numbers.split()  # Розбиваємо стрічку на окремі стрічки - числа
list_of_numbers = [int(i) for i in list_of_numbers]  # Перетворюємо стрічки на цілі числа       
print('Мінімальний елемент:', min(list_of_numbers))
print('Максимальний елемент:', max(list_of_numbers))
# Out:
# 4 6 7
# Мінімальний елемент: 4
# Максимальний елемент: 7

# %% [markdown]
# ### Завдання 2

# %% [markdown]
# #### Програма приймає на вхід два параметри: стать спортсмена(`sex = (f, m)`) та вік спортсмена(`age = [0,100]`).  Спортсмен-дівчина може брати участь у змаганні, якщо її вік більший 18, спортсмен-хлопець - якщо вік більший 16
#
# Якщо введеніть не коректні дані, виведіть повідомлення про помилку

# %%
try:
    sex = input('Введіть стать: ')
    age = int(input('Введіть вік: '))
    if sex not in ('f', 'm') or age not in range(0,101): # якщо введено невалідні дані - викликати помилку
        raise Exception
    elif sex=='f' and age < 18 or sex=='m' and age < 16:  # перевірка відповідності віку спортсмена
        print('Спортсмен НЕ може приймати участь у змаганні! Перевірте вік!')
    else:
        print('Спортсмен може приймати участь у змаганні')
except:
    print('Введено некоректі дані!') # повідомлення у разі помилки
# Out:
# Введіть стать: к
# Введіть вік: 3
# Введено некоректі дані!

# %% [markdown]
# ### Завдання 3

# %% [markdown]
# Для введеного натурального числа побудуйте драбинку.
#
# Наприклад, якщо N = 5, драбинка буде мати вигляд:
#
# &
#
# &&
#
# &&&
#
# &&&&
#
# &&&&&

# %%
N = int(input()) 

for i in range(1, N+1):
    print('&'*i)          # Використаємо роботу оператора множення на стрічку
# Out:
# 5
# &
# &&
# &&&
# &&&&
# &&&&&

# %% [markdown]
# ### Завдання 4

# %% [markdown]
# Із заданого речення виведіть кожне слово і його довжину

# %%
sentence = 'My favourite tutor in academy is Ihor'

list_from_sentence = sentence.split() # розбиваємо речення на слова (через пробіл), отримаємо список
for word in list_from_sentence:       # ітеруємось по списку
    print(word, len(word))

# %% [markdown]
# ### Завдання 5

# %% [markdown]
# Для заданого тексту реалізуйте:
# * Знайдіть кількість слів
# * Знайдіть кількість унікальних слів
# * Своірть словник, де ключе буде слово із тексту, значенням - частота зустрічання в тексті
# * Виведіть топ-3 слів, що найчастіше зустрічаються
#
# Вважаємо, що слово це стрічка з трьох і більше букв, очищена від знаків пунктуації

# %%
text = """До чого ж гарно і весело було в нашому горóді! Ото як вийти з сіней та подивись навколо — геть-чисто все зелене та буйне. А сад було як зацвіте весною! А що робилось на початку літа — огірки цвітуть, гарбузи цвітуть, картопля цвіте. Цвіте малина, смородина, тютюн, квасоля. А соняшника, а маку, буряків, лободи, укропу, моркви! Чого тільки не насадить наша невгамовна мати.

Він був наш добрий дух лугу і риби. Гриби й ягоди збирав він у лісі краще за нас усіх і розмовляв з кіньми, з телятами, з травами, з старою грушею і дубом — з усім живим, що росло і рухалось навколо.
Більш за все на світі любив дід сонце. Він прожив під сонцем коло ста літ, ніколи не ховаючись у холодок. Так під сонцем на погребні, коло яблуні, він і помер, коли прийшов його час.

Дід любив кашляти. Кашляв він часом так довго й гучно, що скільки ми не старалися, ніхто не міг його як слід передражнити. Його кашель чув увесь куток. Старі люди по дідовому кашлю вгадували навіть погоду."""

# %%
import re


# Для того, щоб одне і те ж слово з велікої та малої літери рахувалось як однакове, перетворимо усі літери у тексті на малі

text = text.lower()


# Розбиваємо текст на окремі слова більше 3-х літер за допомогою регулярних виразів.
# list_of_words - список зі слів
# findall*(\w{3,20}... - пошук послідовності символів (букв або цифр) довжиною від 3

list_of_words = re.findall('\w{3,}', text) 



# Кількість слів у тексті дорівнює кількості елементів у списку list_of_words:

print('Кількість слів у тексті:', len(list_of_words))



# Для пошуку кількості унікальних слів зі списку всіх слів створимо set, у якому за визначенням всі елементи - унікальні

unique_words = set(list_of_words)
print('Кількість унікальних слів:', len(unique_words))



# Словник з частотою використання кожного унікального слова 

words_freq = {}
for word in unique_words:
    words_freq[word] = list_of_words.count(word)
#print('Слова та частота їх зустічання у тексті:', words_freq)


# Виведіть топ-3 слів, що найчастіше зустрічаються

print('3 слова, що зустічаються найчастіше: ')
'''

words_freq_copy = words_freq.copy() # робимо копію початкового словника
for i in range(3):
    most_frequent_word = max(words_freq_copy, key=lambda words: words_freq_copy[words]) # шукаємо найчастіше слово
    print(most_frequent_word, words_freq_copy[most_frequent_word])
    words_freq_copy.pop(most_frequent_word) # видаляємо найчастіше слово
'''

# Сортуємо словник по спаданню за частотою зустічання слова 
# отримуємо список кортежів

words_freq_sorted = sorted(words_freq.items(), key = lambda word : word[1], reverse = True) 
print(words_freq_sorted[0:3])
# Out:
# Кількість слів у тексті: 538
# Кількість унікальних слів: 414
# 3 слова, що зустічаються найчастіше:
# [('він', 10), ('дід', 10), ('був', 6)]

# %% [markdown]
# ### Завдання 6

# %% [markdown]
# Напишіть функції, що:
# * рохраховує мінімальне та максимальне значення
# * середнє значення послідовності
# * медіану послідовності
# * частоту кожної цифри в послідовності
# * середнє квадратичне відхилення
#
# Послідовність чисел ганеруємо рандомно

# %%
import random
import statistics # для перевірки коректності роботи написаних функцій
import math

#генеруємо тисячу чисел в діапазоні від 0 до 100
list_with_random_numbers = [random.randint(0,100) for i in range(1000)]



# Функція, що розраховує мінімальне та максимальне значення:

def min_and_max(numbers):
    '''
    Функція, що розраховує мінімальне та максимальне значення
    
    Аргументи:
    numbers - послідовність чисел (тип - list)
    
    Повертає:
        (minimum, maximum) - кортеж (перший елемент - min, другий - max). Тип даних у кортежі залежить від типу у списку numbers 
    
    '''
    minimum = numbers[0]
    maximum = numbers[0]
    for n in numbers:
        if n > maximum:
            maximum = n
        elif n < minimum:
            minimum = n
    return minimum, maximum

# Порівнюємо роботу створеної функції з вбудованими:
print('Функція для знаходження мінімального та максимального значення послідовності')
print('Вбудовані методи:', 'min:', min(list_with_random_numbers), 'max:', max(list_with_random_numbers))
print('Створений метод:', 'min:', min_and_max(list_with_random_numbers)[0], 'max:', min_and_max(list_with_random_numbers)[1])

print()



# Функція, що рохраховує середнє значення послідовності:

def mean_value(numbers):
    s = 0  # змінна для знаходження суми
    
    for n in numbers:
        s = s + n
    return s/len(numbers)

# Порівнюємо роботу створеної функції з вбудованими:
print('Функція для знаходження середнього значення послідовності')
print('Вбудований метод:', statistics.mean(list_with_random_numbers))
print('Створений метод:', mean_value (list_with_random_numbers))
    
print()



# Функція, що рохраховує медіану послідовності:

def my_median(numbers):
    numbers.sort()
    if len(numbers)%2!=0:
        return numbers[len(numbers)//2]
    else:
        return (numbers[len(numbers)//2]+numbers[(len(numbers)//2)-1])/2
    
# Порівнюємо роботу створеної функції з вбудованими:   
print('Функція для знаходження медіани послідовності')
print('Вбудований метод:', statistics.median(list_with_random_numbers))
print('Створений метод:', my_median(list_with_random_numbers)) 

print()


def add_to_dict(key_of_element, current_dict):
    '''
    Функція для додавання нового значення у словник або збільшення значення відповідного ключа на 1
    
    Аргументи:
        key_of_element - ключ, значення якого необхідно збільшити або додати нове зі значенням 1
        current_dict - словник, у який необхідно внести зміни
    '''
    if key_of_element in current_dict.keys():
        current_dict[key_of_element] += 1
    else:
        current_dict[key_of_element] = 1
        
def freq_of_numbers(numbers):
    '''
    Функція, що знаходить частоту входження кожної цифри в послідовності
    
    numbers - список чисел
    
    Повертає: 
    
    словник: ключ - цифра, значення - кількість входжень
    '''
    
    freq_of_digit = {}
    for n in list_with_random_numbers:
        if n == 100:
            add_to_dict(0, freq_of_digit)
            n=10
        else:
            add_to_dict(n%10, freq_of_digit)
            add_to_dict(n//10, freq_of_digit)
    return freq_of_digit
        
            
            
print('Частота кожної цифри в послідовності:')
print(freq_of_numbers(list_with_random_numbers))

print()


# Cереднє квадратичне відхилення 
def mean_square_dev(numbers):
    '''
    Функція, що розраховує Cереднє квадратичне відхилення 
    
    Аргументи:
    numbers - список чисел
    
    Повертає:
    значення Cередього квадратичного відхилення  (float)
    '''
    mean_of_list = mean_value(numbers)
    list_of_square_deviations = [(i-mean_of_list)**2 for i in numbers]
    # mean_square_deviation = (mean_value(list_of_square_deviations))**0.5
    mean_square_deviation = math.sqrt(mean_value(list_of_square_deviations)) # краща точність
    return mean_square_deviation
    
print('Функція для знаходження Cереднього квадратичного відхилення ')
print('Вбудований метод:', statistics.stdev(list_with_random_numbers))
print('Створений метод:', mean_square_dev(list_with_random_numbers))
# Out:
# Функція для знаходження мінімального та максимального значення послідовності
# Вбудовані методи: min: 0 max: 100
# Створений метод: min: 0 max: 100
#
# Функція для знаходження середнього значення послідовності
# Вбудований метод: 51.557
# Створений метод: 51.557
#
# Функція для знаходження медіани послідовності
# Вбудований метод: 51.0
# Створений метод: 51.0
#
# Частота кожної цифри в послідовності:
# {0: 199, 1: 171, 2: 183, 3: 207, 4: 214, 5: 201, 6: 189, 7: 206, 8: 214, 9: 210}
#
# Функція для знаходження Cереднього квадратичного відхилення
# Вбудований метод: 28.881081487158127
# Створений метод: 28.86663733447319
